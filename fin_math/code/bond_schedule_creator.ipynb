# %%
# Bond Schedule Creator (Jupyter launcher)
#
# The implementation lives in `bond_schedule_creator.py` in this same folder.

import os
import sys
from pathlib import Path

try:
    _here = str(Path(__file__).resolve().parent)
except NameError:  # notebook / interactive
    _here = os.getcwd()

sys.path.insert(0, _here)

from bond_schedule_creator import main

main()
